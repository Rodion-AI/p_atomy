# %%
from api.ai import Chunk
chunk = Chunk()
result = chunk.get_answer('Кто вы?')
print(result)
# Out:
# Я представляю компанию Atomy, которая была основана с целью предоставить качественные продукты по доступным ценам и помочь нашим клиентам и партнерам достигать успеха. Мы придерживаемся принципов абсолютного качества и абсолютной цены, а также стремимся к совместному росту и соучастию. Наша философия основана на заботе о людях и их ценности, что делает нас уникальными в сфере сетевого маркетинга.
